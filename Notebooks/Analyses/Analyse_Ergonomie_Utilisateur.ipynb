# %%
import os
os.chdir('/Users/Olivier/anaconda3/envs/guitarsounds')
# %load_ext autoreload

# %%
# %autoreload 2
from guitarsounds import SoundPack, Sound, Signal
from guitarsounds_utils import PathSelector
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

# %% [markdown]
# # 1. Importing files in the analysis tool
#
# ## 1.1 Choosing the number of Sounds to analyze

# %% [markdown]
# ## 1.2 Importing files from disc

# %%
f = PathSelector('soundfiles/')
display(f.accord)
# Out:
# Accordion(children=(SelectMultiple(options=(('[..]', '..'), ('[Chords]', 'Chords'), ('[flax_carbon]', 'flax_ca…

# %%
S = Sound(f.file)

# %%
S.condition()
# Out:
# Signal is too short to be trimmed before onset.

# %%
S.signal.listen()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 1.2 Recording Sounds ?

# %%
def f(x):
    return x

# %%
interact(f, x=10);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3c0968717e64> in <module>
# ----> 1 interact(f, x=10);
#
# NameError: name 'interact' is not defined
