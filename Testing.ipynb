# %%
# %load_ext autoreload

# %%
# %autoreload 2
from soundcomp import Sound, Signal
import soundcomp as sc

# %%
# %matplotlib inline
import librosa
import librosa.display
from soundfile import write
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy
from scipy import signal as sig
from noisereduce import reduce_noise

# %%
# Créer des instance de Son à partir des fichiers
file1 = "test_leste/1-1.wav"
file2 = "soundfiles/Carbon_D0_2.wav"
file3 = "soundfiles/Wood_D0_2.wav"
test1 = Sound(file1)
test2 = Sound(file2)
test3 = Sound(file3)

test1.condition()
test2.condition()
test3.condition()
# Out:
# Signal is too short to be trimmed before onset.
#
# Not sufficient noise in the raw signal, unable to filter.

# %%
plt.figure()
test1.mid.plot(kind='envelop')
plt.xscale('log')

# %%
plt.figure()
test2.mid.plot(kind='envelop')
plt.xscale('log')

# %%
# Échelle de 10-2 à 10^n ... 
# 10 ** -2 = 0.01 s
# sr = 22500/s
# 22500 * 0.01 = 225 -> window à 100 samples de
#100 de 0.01 à 0.1
#1000 de 0.1 à 1
#10000 de

# %%
plt.figure()
x = np.linspace(0.000001,1024,1000)
plt.plot(x, 50*np.log10(x))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
si = test1.signal.signal
sr = test1.signal.sr
i = 1
t = i/sr
envelop = []
frame_size = 100

while i+frame_size < len(si):
    while frame_size*10 > 1/t:
        t = i/sr
        envelop.append(np.max(si[i:i+frame_size]))
        i +=frame_size
    if frame_size < 1000:
        frame_size *=10
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-73393ec27232> in <module>
#       7
#       8 while i+frame_size < len(si):
# ----> 9     while frame_size*10 > 1/t:
#      10         t = i/sr
#      11         envelop.append(np.max(si[i:i+frame_size]))
#
# KeyboardInterrupt:

# %%
sc.double_plot(test1.signal.plot, test2.signal.plot, kind='envelop')

# %%
sc.double_plot(test1.plot_freq_bins, test2.plot_freq_bins)

# %%
test1.plot_freq_bins()
